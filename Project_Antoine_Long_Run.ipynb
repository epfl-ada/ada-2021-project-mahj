# %%
import pandas as pd
import bz2
import json
from urllib.parse import urlparse
import re
import numpy as np
from tld import get_tld

pd.set_option('display.max_colwidth', None) #Print full text
pd.set_option('display.max_rows', 100) #Print full text

# %%
DATA_FOLDER = 'data/'
PROCESSED_DATA_FOLDER = 'processed_data/'

QUOTES_FILE = DATA_FOLDER + 'quotes-2020.json.bz2'
CHUNK_SIZE = 10_000

# %% [markdown]
# ### Utility Functions

# %%
def extract_newspaper(url):
    
    url_pruned = urlparse(url).netloc
    tld = get_tld(url, as_object=True).tld
    url_no_tld = url_pruned.replace('.'+tld,"")
    domain = url_no_tld.split('.')[-1]
    
    return domain

# %% [markdown]
# ### Quotes count statistics

# %%
json_reader = pd.read_json(QUOTES_FILE,lines=True,chunksize=CHUNK_SIZE,compression='bz2') 

quotes_count = 0
unique_quotes_count = 0
not_NONE_quotes_count = 0
for (counter, df_chunk) in enumerate(json_reader):
    
    unique_quotes_count+= len(df_chunk)
    df_chunk['quote_counts']= df_chunk['urls'].apply(lambda urls: len(urls))
    quotes_count += df_chunk['quote_counts'].sum()
    not_NONE_quotes_count += df_chunk[df_chunk['speaker']!='None']['quote_counts'].sum() 
    
    print(f'Iteration {counter+1}')
    print(f'Unique quotes count {unique_quotes_count}')
    print(f'Quotes count {quotes_count}')
    print(f'Not NONE quotes count {not_NONE_quotes_count}')
# Out:
# Iteration 1
# Unique quotes count 10000
# Quotes count 32970
# Not NONE quotes count 21869
# Iteration 2
# Unique quotes count 20000
# Quotes count 67029
# Not NONE quotes count 44352
# Iteration 3
# Unique quotes count 30000
# Quotes count 99716
# Not NONE quotes count 65737
# Iteration 4
# Unique quotes count 40000
# Quotes count 133042
# Not NONE quotes count 87360
# Iteration 5
# Unique quotes count 50000
# Quotes count 166398
# Not NONE quotes count 109730
# Iteration 6
# Unique quotes count 60000
# Quotes count 201008
# Not NONE quotes count 131893
# Iteration 7
# Unique quotes count 70000
# Quotes count 232867
# Not NONE quotes count 152779
# Iteration 8
# Unique quotes count 80000
# Quotes count 262311
# Not NONE quotes count 171819
# Iteration 9
# Unique quotes count 90000
# Quotes count 294956
# Not NONE quotes count 194672
# Iteration 10
# Unique quotes count 100000
# Quotes count 326159
# Not NONE quotes count 215138
# Iteration 11
# Unique quotes count 110000
# Quotes count 358695
# Not NONE quotes count 236464
# Iteration 12
# Unique quotes count 120000
# Quotes count 392645
# Not NONE quotes count 257543
# Iteration 13
# Unique quotes count 130000
# Quotes count 424478
# Not NONE quotes count 278650
# Iteration 14
# Unique quotes count 140000
# Quotes count 458547
# Not NONE quotes count 301335
# Iteration 15
# Unique quotes count 150000
# Quotes count 490791
# Not NONE quotes count 322905
# Iteration 16
# Unique quotes count 160000
# Quotes count 522824
# Not NONE quotes count 344041
# Iteration 17
# Unique quotes count 170000
# Quotes count 555522
# Not NONE quotes count 366581
# Iteration 18
# Unique quotes count 180000
# Quotes count 587538
# Not NONE quotes count 388823
# Iteration 19
# Unique quotes count 190000
# Quotes count 620007
# Not NONE quotes count 410650
# Iteration 20
# Unique quotes count 200000
# Quotes count 651920
# Not NONE quotes count 432475
# Iteration 21
# Unique quotes count 210000
# Quotes count 683818
# Not NONE quotes count 451960
# Iteration 22
# Unique quotes count 220000
# Quotes count 715613
# Not NONE quotes count 473406
# Iteration 23
# Unique quotes count 230000
# Quotes count 747363
# Not NONE quotes count 494038
# Iteration 24
# Unique quotes count 240000
# Quotes count 779380
# Not NONE quotes count 515238
# Iteration 25
# Unique quotes count 250000
# Quotes count 811726
# Not NONE quotes count 537283
# Iteration 26
# Unique quotes count 260000
# Quotes count 844684
# Not NONE quotes count 557825
# Iteration 27
# Unique quotes count 270000
# Quotes count 876694
# Not NONE quotes count 579598
# Iteration 28
# Unique quotes count 280000
# Quotes count 907956
# Not NONE quotes count 600151
# Iteration 29
# Unique quotes count 290000
# Quotes count 940780
# Not NONE quotes count 621043
# Iteration 30
# Unique quotes count 300000
# Quotes count 970054
# Not NONE quotes count 639910
# Iteration 31
# Unique quotes count 310000
# Quotes count 1003308
# Not NONE quotes count 661631
# Iteration 32
# Unique quotes count 320000
# Quotes count 1034647
# Not NONE quotes count 681711
# Iteration 33
# Unique quotes count 330000
# Quotes count 1065834
# Not NONE quotes count 702000
# Iteration 34
# Unique quotes count 340000
# Quotes count 1098972
# Not NONE quotes count 723843
# Iteration 35
# Unique quotes count 350000
# Quotes count 1132378
# Not NONE quotes count 745994
# Iteration 36
# Unique quotes count 360000
# Quotes count 1163994
# Not NONE quotes count 766618
# Iteration 37
# Unique quotes count 370000
# Quotes count 1196801
# Not NONE quotes count 787874
# Iteration 38
# Unique quotes count 380000
# Quotes count 1233227
# Not NONE quotes count 812474
# Iteration 39
# Unique quotes count 390000
# Quotes count 1265780
# Not NONE quotes count 833247
# Iteration 40
# Unique quotes count 400000
# Quotes count 1298455
# Not NONE quotes count 854853
# Iteration 41
# Unique quotes count 410000
# Quotes count 1330924
# Not NONE quotes count 876594
# Iteration 42
# Unique quotes count 420000
# Quotes count 1366041
# Not NONE quotes count 898035
# Iteration 43
# Unique quotes count 430000
# Quotes count 1398016
# Not NONE quotes count 919474
# Iteration 44
# Unique quotes count 440000
# Quotes count 1431733
# Not NONE quotes count 942364
# Iteration 45
# Unique quotes count 450000
# Quotes count 1464121
# Not NONE quotes count 963664
# Iteration 46
# Unique quotes count 460000
# Quotes count 1496246
# Not NONE quotes count 983932
# Iteration 47
# Unique quotes count 470000
# Quotes count 1529700
# Not NONE quotes count 1005599
# Iteration 48
# Unique quotes count 480000
# Quotes count 1562444
# Not NONE quotes count 1026654
# Iteration 49
# Unique quotes count 490000
# Quotes count 1593718
# Not NONE quotes count 1046544
# Iteration 50
# Unique quotes count 500000
# Quotes count 1626817
# Not NONE quotes count 1067869
# Iteration 51
# Unique quotes count 510000
# Quotes count 1658351
# Not NONE quotes count 1088411
# Iteration 52
# Unique quotes count 520000
# Quotes count 1691470
# Not NONE quotes count 1110140
# Iteration 53
# Unique quotes count 530000
# Quotes count 1724647
# Not NONE quotes count 1131272
# Iteration 54
# Unique quotes count 540000
# Quotes count 1755671
# Not NONE quotes count 1151758
# Iteration 55
# Unique quotes count 550000
# Quotes count 1789349
# Not NONE quotes count 1172919
# Iteration 56
# Unique quotes count 560000
# Quotes count 1822785
# Not NONE quotes count 1194925
# Iteration 57
# Unique quotes count 570000
# Quotes count 1855635
# Not NONE quotes count 1215947
# Iteration 58
# Unique quotes count 580000
# Quotes count 1888436
# Not NONE quotes count 1236982
# Iteration 59
# Unique quotes count 590000
# Quotes count 1919681
# Not NONE quotes count 1257984
# Iteration 60
# Unique quotes count 600000
# Quotes count 1953841
# Not NONE quotes count 1280786
# Iteration 61
# Unique quotes count 610000
# Quotes count 1988589
# Not NONE quotes count 1304637
# Iteration 62
# Unique quotes count 620000
# Quotes count 2021021
# Not NONE quotes count 1324263
# Iteration 63
# Unique quotes count 630000
# Quotes count 2055057
# Not NONE quotes count 1347458
# Iteration 64
# Unique quotes count 640000
# Quotes count 2088274
# Not NONE quotes count 1368949
# Iteration 65
# Unique quotes count 650000
# Quotes count 2119675
# Not NONE quotes count 1389716
# Iteration 66
# Unique quotes count 660000
# Quotes count 2151398
# Not NONE quotes count 1410236
# Iteration 67
# Unique quotes count 670000
# Quotes count 2182625
# Not NONE quotes count 1430575
# Iteration 68
# Unique quotes count 680000
# Quotes count 2214271
# Not NONE quotes count 1450615
# Iteration 69
# Unique quotes count 690000
# Quotes count 2244800
# Not NONE quotes count 1471259
# Iteration 70
# Unique quotes count 700000
# Quotes count 2275143
# Not NONE quotes count 1490846
# Iteration 71
# Unique quotes count 710000
# Quotes count 2306207
# Not NONE quotes count 1512382
# Iteration 72
# Unique quotes count 720000
# Quotes count 2337977
# Not NONE quotes count 1533461
# Iteration 73
# Unique quotes count 730000
# Quotes count 2371995
# Not NONE quotes count 1555226
# Iteration 74
# Unique quotes count 740000
# Quotes count 2404173
# Not NONE quotes count 1575950
# Iteration 75
# Unique quotes count 750000
# Quotes count 2434957
# Not NONE quotes count 1596735
# Iteration 76
# Unique quotes count 760000
# Quotes count 2468984
# Not NONE quotes count 1619354
# Iteration 77
# Unique quotes count 770000
# Quotes count 2501965
# Not NONE quotes count 1641275
# Iteration 78
# Unique quotes count 780000
# Quotes count 2532939
# Not NONE quotes count 1662220
# Iteration 79
# Unique quotes count 790000
# Quotes count 2568364
# Not NONE quotes count 1684642
# Iteration 80
# Unique quotes count 800000
# Quotes count 2600658
# Not NONE quotes count 1706182
# Iteration 81
# Unique quotes count 810000
# Quotes count 2632234
# Not NONE quotes count 1727525
# Iteration 82
# Unique quotes count 820000
# Quotes count 2664728
# Not NONE quotes count 1748443
# Iteration 83
# Unique quotes count 830000
# Quotes count 2695730
# Not NONE quotes count 1769181
# Iteration 84
# Unique quotes count 840000
# Quotes count 2730902
# Not NONE quotes count 1792262
# Iteration 85
# Unique quotes count 850000
# Quotes count 2764029
# Not NONE quotes count 1812934
# Iteration 86
# Unique quotes count 860000
# Quotes count 2795766
# Not NONE quotes count 1834411
# Iteration 87
# Unique quotes count 870000
# Quotes count 2825841
# Not NONE quotes count 1854479
# Iteration 88
# Unique quotes count 880000
# Quotes count 2858083
# Not NONE quotes count 1875557
# Iteration 89
# Unique quotes count 890000
# Quotes count 2890902
# Not NONE quotes count 1898060
# Iteration 90
# Unique quotes count 900000
# Quotes count 2921979
# Not NONE quotes count 1919260
# Iteration 91
# Unique quotes count 910000
# Quotes count 2955004
# Not NONE quotes count 1940777
# Iteration 92
# Unique quotes count 920000
# Quotes count 2987804
# Not NONE quotes count 1962770
# Iteration 93
# Unique quotes count 930000
# Quotes count 3020328
# Not NONE quotes count 1984890
# Iteration 94
# Unique quotes count 940000
# Quotes count 3052080
# Not NONE quotes count 2006481
# Iteration 95
# Unique quotes count 950000
# Quotes count 3084852
# Not NONE quotes count 2027938
# Iteration 96
# Unique quotes count 960000
# Quotes count 3117657
# Not NONE quotes count 2049308
# Iteration 97
# Unique quotes count 970000
# Quotes count 3150044
# Not NONE quotes count 2070314
# Iteration 98
# Unique quotes count 980000
# Quotes count 3182374
# Not NONE quotes count 2091004
# Iteration 99
# Unique quotes count 990000
# Quotes count 3217409
# Not NONE quotes count 2114362
# Iteration 100
# Unique quotes count 1000000
# Quotes count 3251315
# Not NONE quotes count 2138377
# Iteration 101
# Unique quotes count 1010000
# Quotes count 3284549
# Not NONE quotes count 2160409
# Iteration 102
# Unique quotes count 1020000
# Quotes count 3316111
# Not NONE quotes count 2181250
# Iteration 103
# Unique quotes count 1030000
# Quotes count 3350817
# Not NONE quotes count 2203261
# Iteration 104
# Unique quotes count 1040000
# Quotes count 3383368
# Not NONE quotes count 2224756
# Iteration 105
# Unique quotes count 1050000
# Quotes count 3416807
# Not NONE quotes count 2246628
# Iteration 106
# Unique quotes count 1060000
# Quotes count 3449937
# Not NONE quotes count 2269732
# Iteration 107
# Unique quotes count 1070000
# Quotes count 3483771
# Not NONE quotes count 2292349
# Iteration 108
# Unique quotes count 1080000
# Quotes count 3514610
# Not NONE quotes count 2312540
# Iteration 109
# Unique quotes count 1090000
# Quotes count 3547584
# Not NONE quotes count 2334499
# Iteration 110
# Unique quotes count 1100000
# Quotes count 3579728
# Not NONE quotes count 2356643
# Iteration 111
# Unique quotes count 1110000
# Quotes count 3613382
# Not NONE quotes count 2377611
# Iteration 112
# Unique quotes count 1120000
# Quotes count 3643955
# Not NONE quotes count 2397136
# Iteration 113
# Unique quotes count 1130000
# Quotes count 3674539
# Not NONE quotes count 2416274
# Iteration 114
# Unique quotes count 1140000
# Quotes count 3706260
# Not NONE quotes count 2436804
# Iteration 115
# Unique quotes count 1150000
# Quotes count 3737465
# Not NONE quotes count 2456430
# Iteration 116
# Unique quotes count 1160000
# Quotes count 3768413
# Not NONE quotes count 2477016
# Iteration 117
# Unique quotes count 1170000
# Quotes count 3803760
# Not NONE quotes count 2499807
# Iteration 118
# Unique quotes count 1180000
# Quotes count 3835093
# Not NONE quotes count 2520224
# Iteration 119
# Unique quotes count 1190000
# Quotes count 3868358
# Not NONE quotes count 2542199
# Iteration 120
# Unique quotes count 1200000
# Quotes count 3899726
# Not NONE quotes count 2562457
# Iteration 121
# Unique quotes count 1210000
# Quotes count 3931751
# Not NONE quotes count 2583130
# Iteration 122
# Unique quotes count 1220000
# Quotes count 3963031
# Not NONE quotes count 2604455
# Iteration 123
# Unique quotes count 1230000
# Quotes count 3994778
# Not NONE quotes count 2624371
# Iteration 124
# Unique quotes count 1240000
# Quotes count 4026064
# Not NONE quotes count 2644250
# Iteration 125
# Unique quotes count 1250000
# Quotes count 4058313
# Not NONE quotes count 2664610
# Iteration 126
# Unique quotes count 1260000
# Quotes count 4090908
# Not NONE quotes count 2686095
# Iteration 127
# Unique quotes count 1270000
# Quotes count 4123516
# Not NONE quotes count 2707881
# Iteration 128
# Unique quotes count 1280000
# Quotes count 4153599
# Not NONE quotes count 2727967
# Iteration 129
# Unique quotes count 1290000
# Quotes count 4185732
# Not NONE quotes count 2749481
# Iteration 130
# Unique quotes count 1300000
# Quotes count 4218209
# Not NONE quotes count 2770631
# Iteration 131
# Unique quotes count 1310000
# Quotes count 4254050
# Not NONE quotes count 2793448
# Iteration 132
# Unique quotes count 1320000
# Quotes count 4285292
# Not NONE quotes count 2813894
# Iteration 133
# Unique quotes count 1330000
# Quotes count 4317922
# Not NONE quotes count 2836125
# Iteration 134
# Unique quotes count 1340000
# Quotes count 4347892
# Not NONE quotes count 2855744
# Iteration 135
# Unique quotes count 1350000
# Quotes count 4379631
# Not NONE quotes count 2876409
# Iteration 136
# Unique quotes count 1360000
# Quotes count 4413315
# Not NONE quotes count 2897073
# Iteration 137
# Unique quotes count 1370000
# Quotes count 4444264
# Not NONE quotes count 2917642
# Iteration 138
# Unique quotes count 1380000
# Quotes count 4476857
# Not NONE quotes count 2938352
# Iteration 139
# Unique quotes count 1390000
# Quotes count 4510535
# Not NONE quotes count 2962097
# Iteration 140
# Unique quotes count 1400000
# Quotes count 4540499
# Not NONE quotes count 2981495
# Iteration 141
# Unique quotes count 1410000
# Quotes count 4573135
# Not NONE quotes count 3002585
# Iteration 142
# Unique quotes count 1420000
# Quotes count 4606088
# Not NONE quotes count 3025366
# Iteration 143
# Unique quotes count 1430000
# Quotes count 4636399
# Not NONE quotes count 3045439
# Iteration 144
# Unique quotes count 1440000
# Quotes count 4671703
# Not NONE quotes count 3069012
# Iteration 145
# Unique quotes count 1450000
# Quotes count 4702094
# Not NONE quotes count 3088851
# Iteration 146
# Unique quotes count 1460000
# Quotes count 4734213
# Not NONE quotes count 3110271
# Iteration 147
# Unique quotes count 1470000
# Quotes count 4765978
# Not NONE quotes count 3130621
# Iteration 148
# Unique quotes count 1480000
# Quotes count 4798372
# Not NONE quotes count 3152729
# Iteration 149
# Unique quotes count 1490000
# Quotes count 4830997
# Not NONE quotes count 3174427
# Iteration 150
# Unique quotes count 1500000
# Quotes count 4862512
# Not NONE quotes count 3195919
# Iteration 151
# Unique quotes count 1510000
# Quotes count 4893645
# Not NONE quotes count 3215708
# Iteration 152
# Unique quotes count 1520000
# Quotes count 4926455
# Not NONE quotes count 3237244
# Iteration 153
# Unique quotes count 1530000
# Quotes count 4957403
# Not NONE quotes count 3257560
# Iteration 154
# Unique quotes count 1540000
# Quotes count 4988749
# Not NONE quotes count 3278230
# Iteration 155
# Unique quotes count 1550000
# Quotes count 5021522
# Not NONE quotes count 3299653
# Iteration 156
# Unique quotes count 1560000
# Quotes count 5054308
# Not NONE quotes count 3321457
# Iteration 157
# Unique quotes count 1570000
# Quotes count 5085808
# Not NONE quotes count 3342549
# Iteration 158
# Unique quotes count 1580000
# Quotes count 5119862
# Not NONE quotes count 3364157
# Iteration 159
# Unique quotes count 1590000
# Quotes count 5150754
# Not NONE quotes count 3384677
# Iteration 160
# Unique quotes count 1600000
# Quotes count 5184517
# Not NONE quotes count 3407460
# Iteration 161
# Unique quotes count 1610000
# Quotes count 5217487
# Not NONE quotes count 3428837
# Iteration 162
# Unique quotes count 1620000
# Quotes count 5248831
# Not NONE quotes count 3450026
# Iteration 163
# Unique quotes count 1630000
# Quotes count 5280564
# Not NONE quotes count 3470964
# Iteration 164
# Unique quotes count 1640000
# Quotes count 5316149
# Not NONE quotes count 3492327
# Iteration 165
# Unique quotes count 1650000
# Quotes count 5348777
# Not NONE quotes count 3514656
# Iteration 166
# Unique quotes count 1660000
# Quotes count 5379993
# Not NONE quotes count 3535223
# Iteration 167
# Unique quotes count 1670000
# Quotes count 5413749
# Not NONE quotes count 3558633
# Iteration 168
# Unique quotes count 1680000
# Quotes count 5448268
# Not NONE quotes count 3581947
# Iteration 169
# Unique quotes count 1690000
# Quotes count 5480183
# Not NONE quotes count 3603284
# Iteration 170
# Unique quotes count 1700000
# Quotes count 5511720
# Not NONE quotes count 3623479
# Iteration 171
# Unique quotes count 1710000
# Quotes count 5546223
# Not NONE quotes count 3644778
# Iteration 172
# Unique quotes count 1720000
# Quotes count 5577818
# Not NONE quotes count 3665019
# Iteration 173
# Unique quotes count 1730000
# Quotes count 5611212
# Not NONE quotes count 3686022
# Iteration 174
# Unique quotes count 1740000
# Quotes count 5643236
# Not NONE quotes count 3707038
# Iteration 175
# Unique quotes count 1750000
# Quotes count 5675235
# Not NONE quotes count 3727644
# Iteration 176
# Unique quotes count 1760000
# Quotes count 5707982
# Not NONE quotes count 3750514
# Iteration 177
# Unique quotes count 1770000
# Quotes count 5738047
# Not NONE quotes count 3770024
# Iteration 178
# Unique quotes count 1780000
# Quotes count 5770541
# Not NONE quotes count 3791365
# Iteration 179
# Unique quotes count 1790000
# Quotes count 5803829
# Not NONE quotes count 3811877
# Iteration 180
# Unique quotes count 1800000
# Quotes count 5837336
# Not NONE quotes count 3833956
# Iteration 181
# Unique quotes count 1810000
# Quotes count 5868697
# Not NONE quotes count 3855436
# Iteration 182
# Unique quotes count 1820000
# Quotes count 5899713
# Not NONE quotes count 3875343
# Iteration 183
# Unique quotes count 1830000
# Quotes count 5932024
# Not NONE quotes count 3896389
# Iteration 184
# Unique quotes count 1840000
# Quotes count 5965044
# Not NONE quotes count 3918286
# Iteration 185
# Unique quotes count 1850000
# Quotes count 5998091
# Not NONE quotes count 3940070
# Iteration 186
# Unique quotes count 1860000
# Quotes count 6030646
# Not NONE quotes count 3961756
# Iteration 187
# Unique quotes count 1870000
# Quotes count 6065971
# Not NONE quotes count 3984115
# Iteration 188
# Unique quotes count 1880000
# Quotes count 6096211
# Not NONE quotes count 4003900
# Iteration 189
# Unique quotes count 1890000
# Quotes count 6129226
# Not NONE quotes count 4026834
# Iteration 190
# Unique quotes count 1900000
# Quotes count 6162261
# Not NONE quotes count 4048608
# Iteration 191
# Unique quotes count 1910000
# Quotes count 6192923
# Not NONE quotes count 4068390
# Iteration 192
# Unique quotes count 1920000
# Quotes count 6224625
# Not NONE quotes count 4090661
# Iteration 193
# Unique quotes count 1930000
# Quotes count 6256379
# Not NONE quotes count 4111204
# Iteration 194
# Unique quotes count 1940000
# Quotes count 6290486
# Not NONE quotes count 4133275
# Iteration 195
# Unique quotes count 1950000
# Quotes count 6322226
# Not NONE quotes count 4154323
# Iteration 196
# Unique quotes count 1960000
# Quotes count 6356825
# Not NONE quotes count 4177787
# Iteration 197
# Unique quotes count 1970000
# Quotes count 6386986
# Not NONE quotes count 4197834
# Iteration 198
# Unique quotes count 1980000
# Quotes count 6421186
# Not NONE quotes count 4219011
# Iteration 199
# Unique quotes count 1990000
# Quotes count 6452958
# Not NONE quotes count 4240928
# Iteration 200
# Unique quotes count 2000000
# Quotes count 6486319
# Not NONE quotes count 4263805
# Iteration 201
# Unique quotes count 2010000
# Quotes count 6519457
# Not NONE quotes count 4286166
# Iteration 202
# Unique quotes count 2020000
# Quotes count 6551981
# Not NONE quotes count 4308485
# Iteration 203
# Unique quotes count 2030000
# Quotes count 6583541
# Not NONE quotes count 4328646
# Iteration 204
# Unique quotes count 2040000
# Quotes count 6615715
# Not NONE quotes count 4350273
# Iteration 205
# Unique quotes count 2050000
# Quotes count 6647195
# Not NONE quotes count 4371020
# Iteration 206
# Unique quotes count 2060000
# Quotes count 6681252
# Not NONE quotes count 4395251
# Iteration 207
# Unique quotes count 2070000
# Quotes count 6713862
# Not NONE quotes count 4416342
# Iteration 208
# Unique quotes count 2080000
# Quotes count 6746126
# Not NONE quotes count 4437651
# Iteration 209
# Unique quotes count 2090000
# Quotes count 6780374
# Not NONE quotes count 4459165
# Iteration 210
# Unique quotes count 2100000
# Quotes count 6815835
# Not NONE quotes count 4483276
# Iteration 211
# Unique quotes count 2110000
# Quotes count 6846688
# Not NONE quotes count 4503140
# Iteration 212
# Unique quotes count 2120000
# Quotes count 6879047
# Not NONE quotes count 4524988
# Iteration 213
# Unique quotes count 2130000
# Quotes count 6912900
# Not NONE quotes count 4547656
# Iteration 214
# Unique quotes count 2140000
# Quotes count 6946785
# Not NONE quotes count 4570208
# Iteration 215
# Unique quotes count 2150000
# Quotes count 6976868
# Not NONE quotes count 4589895
# Iteration 216
# Unique quotes count 2160000
# Quotes count 7007699
# Not NONE quotes count 4610263
# Iteration 217
# Unique quotes count 2170000
# Quotes count 7041468
# Not NONE quotes count 4632588
# Iteration 218
# Unique quotes count 2180000
# Quotes count 7073046
# Not NONE quotes count 4653310
# Iteration 219
# Unique quotes count 2190000
# Quotes count 7107500
# Not NONE quotes count 4676262
# Iteration 220
# Unique quotes count 2200000
# Quotes count 7139259
# Not NONE quotes count 4696765
# Iteration 221
# Unique quotes count 2210000
# Quotes count 7172095
# Not NONE quotes count 4719515
# Iteration 222
# Unique quotes count 2220000
# Quotes count 7203678
# Not NONE quotes count 4740761
# Iteration 223
# Unique quotes count 2230000
# Quotes count 7237084
# Not NONE quotes count 4762901
# Iteration 224
# Unique quotes count 2240000
# Quotes count 7267834
# Not NONE quotes count 4783083
# Iteration 225
# Unique quotes count 2250000
# Quotes count 7300629
# Not NONE quotes count 4805006
# Iteration 226
# Unique quotes count 2260000
# Quotes count 7334426
# Not NONE quotes count 4827745
# Iteration 227
# Unique quotes count 2270000
# Quotes count 7366822
# Not NONE quotes count 4850226
# Iteration 228
# Unique quotes count 2280000
# Quotes count 7399371
# Not NONE quotes count 4871347
# Iteration 229
# Unique quotes count 2290000
# Quotes count 7430706
# Not NONE quotes count 4890800
# Iteration 230
# Unique quotes count 2300000
# Quotes count 7463769
# Not NONE quotes count 4912862
# Iteration 231
# Unique quotes count 2310000
# Quotes count 7496379
# Not NONE quotes count 4933421
# Iteration 232
# Unique quotes count 2320000
# Quotes count 7529510
# Not NONE quotes count 4955046
# Iteration 233
# Unique quotes count 2330000
# Quotes count 7563066
# Not NONE quotes count 4977819
# Iteration 234
# Unique quotes count 2340000
# Quotes count 7596471
# Not NONE quotes count 5000150
# Iteration 235
# Unique quotes count 2350000
# Quotes count 7633848
# Not NONE quotes count 5021298
# Iteration 236
# Unique quotes count 2360000
# Quotes count 7666244
# Not NONE quotes count 5042021
# Iteration 237
# Unique quotes count 2370000
# Quotes count 7697878
# Not NONE quotes count 5062471
# Iteration 238
# Unique quotes count 2380000
# Quotes count 7731230
# Not NONE quotes count 5083775
# Iteration 239
# Unique quotes count 2390000
# Quotes count 7763512
# Not NONE quotes count 5104818
# Iteration 240
# Unique quotes count 2400000
# Quotes count 7797165
# Not NONE quotes count 5127567
# Iteration 241
# Unique quotes count 2410000
# Quotes count 7830524
# Not NONE quotes count 5149744
# Iteration 242
# Unique quotes count 2420000
# Quotes count 7862613
# Not NONE quotes count 5170589
# Iteration 243
# Unique quotes count 2430000
# Quotes count 7894220
# Not NONE quotes count 5191158
# Iteration 244
# Unique quotes count 2440000
# Quotes count 7926645
# Not NONE quotes count 5213867
# Iteration 245
# Unique quotes count 2450000
# Quotes count 7959087
# Not NONE quotes count 5235043
# Iteration 246
# Unique quotes count 2460000
# Quotes count 7992103
# Not NONE quotes count 5257107
# Iteration 247
# Unique quotes count 2470000
# Quotes count 8024723
# Not NONE quotes count 5278515
# Iteration 248
# Unique quotes count 2480000
# Quotes count 8059034
# Not NONE quotes count 5300483
# Iteration 249
# Unique quotes count 2490000
# Quotes count 8091338
# Not NONE quotes count 5322575
# Iteration 250
# Unique quotes count 2500000
# Quotes count 8124621
# Not NONE quotes count 5344424
# Iteration 251
# Unique quotes count 2510000
# Quotes count 8158026
# Not NONE quotes count 5367066
# Iteration 252
# Unique quotes count 2520000
# Quotes count 8191929
# Not NONE quotes count 5389097
# Iteration 253
# Unique quotes count 2530000
# Quotes count 8224086
# Not NONE quotes count 5410204
# Iteration 254
# Unique quotes count 2540000
# Quotes count 8257163
# Not NONE quotes count 5432285
# Iteration 255
# Unique quotes count 2550000
# Quotes count 8290716
# Not NONE quotes count 5454358
# Iteration 256
# Unique quotes count 2560000
# Quotes count 8324580
# Not NONE quotes count 5476382
# Iteration 257
# Unique quotes count 2570000
# Quotes count 8357550
# Not NONE quotes count 5497400
# Iteration 258
# Unique quotes count 2580000
# Quotes count 8387838
# Not NONE quotes count 5517286
# Iteration 259
# Unique quotes count 2590000
# Quotes count 8421109
# Not NONE quotes count 5539150
# Iteration 260
# Unique quotes count 2600000
# Quotes count 8454415
# Not NONE quotes count 5561512
# Iteration 261
# Unique quotes count 2610000
# Quotes count 8486365
# Not NONE quotes count 5583053
# Iteration 262
# Unique quotes count 2620000
# Quotes count 8518805
# Not NONE quotes count 5604799
# Iteration 263
# Unique quotes count 2630000
# Quotes count 8550925
# Not NONE quotes count 5626357
# Iteration 264
# Unique quotes count 2640000
# Quotes count 8584221
# Not NONE quotes count 5648981
# Iteration 265
# Unique quotes count 2650000
# Quotes count 8614854
# Not NONE quotes count 5669351
# Iteration 266
# Unique quotes count 2660000
# Quotes count 8645729
# Not NONE quotes count 5689126
# Iteration 267
# Unique quotes count 2670000
# Quotes count 8677784
# Not NONE quotes count 5710438
# Iteration 268
# Unique quotes count 2680000
# Quotes count 8711152
# Not NONE quotes count 5732312
# Iteration 269
# Unique quotes count 2690000
# Quotes count 8745003
# Not NONE quotes count 5753885
# Iteration 270
# Unique quotes count 2700000
# Quotes count 8779194
# Not NONE quotes count 5775123
# Iteration 271
# Unique quotes count 2710000
# Quotes count 8809677
# Not NONE quotes count 5794702
# Iteration 272
# Unique quotes count 2720000
# Quotes count 8840672
# Not NONE quotes count 5814923
# Iteration 273
# Unique quotes count 2730000
# Quotes count 8875575
# Not NONE quotes count 5837149
# Iteration 274
# Unique quotes count 2740000
# Quotes count 8907205
# Not NONE quotes count 5858746
# Iteration 275
# Unique quotes count 2750000
# Quotes count 8939698
# Not NONE quotes count 5879563
# Iteration 276
# Unique quotes count 2760000
# Quotes count 8972805
# Not NONE quotes count 5900741
# Iteration 277
# Unique quotes count 2770000
# Quotes count 9004628
# Not NONE quotes count 5920791
# Iteration 278
# Unique quotes count 2780000
# Quotes count 9037857
# Not NONE quotes count 5942685
# Iteration 279
# Unique quotes count 2790000
# Quotes count 9069325
# Not NONE quotes count 5963368
# Iteration 280
# Unique quotes count 2800000
# Quotes count 9101131
# Not NONE quotes count 5984456
# Iteration 281
# Unique quotes count 2810000
# Quotes count 9136580
# Not NONE quotes count 6006366
# Iteration 282
# Unique quotes count 2820000
# Quotes count 9168081
# Not NONE quotes count 6027762
# Iteration 283
# Unique quotes count 2830000
# Quotes count 9201678
# Not NONE quotes count 6050032
# Iteration 284
# Unique quotes count 2840000
# Quotes count 9233878
# Not NONE quotes count 6071267
# Iteration 285
# Unique quotes count 2850000
# Quotes count 9267121
# Not NONE quotes count 6093632
# Iteration 286
# Unique quotes count 2860000
# Quotes count 9298646
# Not NONE quotes count 6113766
# Iteration 287
# Unique quotes count 2870000
# Quotes count 9331188
# Not NONE quotes count 6135780
# Iteration 288
# Unique quotes count 2880000
# Quotes count 9364923
# Not NONE quotes count 6159303
# Iteration 289
# Unique quotes count 2890000
# Quotes count 9398926
# Not NONE quotes count 6181580
# Iteration 290
# Unique quotes count 2900000
# Quotes count 9431812
# Not NONE quotes count 6202399
# Iteration 291
# Unique quotes count 2910000
# Quotes count 9464543
# Not NONE quotes count 6223764
# Iteration 292
# Unique quotes count 2920000
# Quotes count 9496901
# Not NONE quotes count 6244917
# Iteration 293
# Unique quotes count 2930000
# Quotes count 9529280
# Not NONE quotes count 6266931
# Iteration 294
# Unique quotes count 2940000
# Quotes count 9563152
# Not NONE quotes count 6290030
# Iteration 295
# Unique quotes count 2950000
# Quotes count 9596877
# Not NONE quotes count 6311960
# Iteration 296
# Unique quotes count 2960000
# Quotes count 9629639
# Not NONE quotes count 6333126
# Iteration 297
# Unique quotes count 2970000
# Quotes count 9662805
# Not NONE quotes count 6355431
# Iteration 298
# Unique quotes count 2980000
# Quotes count 9695531
# Not NONE quotes count 6375629
# Iteration 299
# Unique quotes count 2990000
# Quotes count 9727825
# Not NONE quotes count 6397030
# Iteration 300
# Unique quotes count 3000000
# Quotes count 9760208
# Not NONE quotes count 6418644
# Iteration 301
# Unique quotes count 3010000
# Quotes count 9792030
# Not NONE quotes count 6439630
# Iteration 302
# Unique quotes count 3020000
# Quotes count 9824273
# Not NONE quotes count 6459815
# Iteration 303
# Unique quotes count 3030000
# Quotes count 9857255
# Not NONE quotes count 6481527
# Iteration 304
# Unique quotes count 3040000
# Quotes count 9891131
# Not NONE quotes count 6505089
# Iteration 305
# Unique quotes count 3050000
# Quotes count 9921831
# Not NONE quotes count 6525704
# Iteration 306
# Unique quotes count 3060000
# Quotes count 9956724
# Not NONE quotes count 6548306
# Iteration 307
# Unique quotes count 3070000
# Quotes count 9992510
# Not NONE quotes count 6571333
# Iteration 308
# Unique quotes count 3080000
# Quotes count 10024058
# Not NONE quotes count 6592110
# Iteration 309
# Unique quotes count 3090000
# Quotes count 10057140
# Not NONE quotes count 6613818
# Iteration 310
# Unique quotes count 3100000
# Quotes count 10088415
# Unique quotes count 5030000
# Quotes count 16360167
# Not NONE quotes count 10742204
# Iteration 504
# Unique quotes count 5040000
# Quotes count 16392718
# Not NONE quotes count 10763613
# Iteration 505
# Unique quotes count 5050000
# Quotes count 16425470
# Not NONE quotes count 10785813
# Iteration 506
# Unique quotes count 5060000
# Quotes count 16457373
# Not NONE quotes count 10807324
# Iteration 507
# Unique quotes count 5070000
# Quotes count 16491214
# Not NONE quotes count 10829823
# Iteration 508
# Unique quotes count 5080000
# Quotes count 16524796
# Not NONE quotes count 10851619
# Iteration 509
# Unique quotes count 5090000
# Quotes count 16558220
# Not NONE quotes count 10874185
# Iteration 510
# Unique quotes count 5100000
# Quotes count 16593259
# Not NONE quotes count 10896042
# Iteration 511
# Unique quotes count 5110000
# Quotes count 16625364
# Not NONE quotes count 10916075
# Iteration 512
# Unique quotes count 5120000
# Quotes count 16658797
# Not NONE quotes count 10937910
# Iteration 513
# Unique quotes count 5130000
# Quotes count 16692543
# Not NONE quotes count 10958950
# Iteration 514
# Unique quotes count 5140000
# Quotes count 16724215
# Not NONE quotes count 10980469
# Iteration 515
# Unique quotes count 5150000
# Quotes count 16757650
# Not NONE quotes count 11001651
# Iteration 516
# Unique quotes count 5160000
# Quotes count 16788283
# Not NONE quotes count 11021869
# Iteration 517
# Unique quotes count 5170000
# Quotes count 16818869
# Not NONE quotes count 11042645
# Iteration 518
# Unique quotes count 5180000
# Quotes count 16850687
# Not NONE quotes count 11064173
# Iteration 519
# Unique quotes count 5190000
# Quotes count 16883019
# Not NONE quotes count 11086249
# Iteration 520
# Unique quotes count 5200000
# Quotes count 16914550
# Not NONE quotes count 11106731
# Iteration 521
# Unique quotes count 5210000
# Quotes count 16945899
# Not NONE quotes count 11127337
# Iteration 522
# Unique quotes count 5220000
# Quotes count 16977467
# Not NONE quotes count 11148256
# Iteration 523
# Unique quotes count 5230000
# Quotes count 17009345
# Not NONE quotes count 11168731
# Iteration 524
# Unique quotes count 5240000
# Quotes count 17043389
# Not NONE quotes count 11190904
# Iteration 525
# Unique quotes count 5244449
# Quotes count 17057653
# Not NONE quotes count 11200295

# %%
print(f'Number of unique quotes {unique_quotes_count}')

#We are not using num_occurences but rather the number of urls to quantify the number of quotes because
# around 3% of quotes appear multiple times in the same article which increases numOccurences but is not 
#relevant in this study
print(f'Quotes appearance count {quotes_count}')
print(f'Quotes appearance count where speaker is not None {not_NONE_quotes_count}')
# Out:
# Number of unique quotes 5244449
# Quotes appearance count 17057653
# Quotes appearance count where speaker is not None 11200295

# %% [markdown]
# ### Create speaker-newspaper dataframe
# df['newspaper','speaker','proba'] with possible duplicates if speaker was cited multiple times by the newspaper.
# Quotes with the most probable speaker cited as None are kept and removed furhter down the pipeline if necessary.

# %%
FILE_SPEAKERS = PROCESSED_DATA_FOLDER +"processed-speaker-2020.csv.bz2"

json_reader = pd.read_json(QUOTES_FILE,lines=True,chunksize=CHUNK_SIZE,compression='bz2') 

for (counter, df_chunk) in enumerate(json_reader):

    print(f"Process chunk {counter+1}")
    
    df_chunk = df_chunk[["probas","urls","speaker"]]
    
    df_chunk["proba"] = df_chunk["probas"].apply(lambda probas: float(probas[0][1]))
    
    df_chunk = df_chunk.explode("urls")
    df_chunk["newspaper"] = df_chunk["urls"].apply(extract_newspaper)
    
    #df_speakers = df_chunk[df_chunk["speaker"] != "None"][["newspaper", "speaker","proba"]]
    #We keep None values and remove it further down the pipeline
    df_speakers = df_chunk[["newspaper", "speaker","proba"]]
    
    add_header = (counter==0)
    write_mode = 'w' if counter == 0 else 'a'
    df_speakers.to_csv(FILE_SPEAKERS,header = add_header,index=False, mode=write_mode,compression='bz2')
# Out:
# Process chunk 1
# /var/folders/c6/nkvhnnln1739v3k9ryxjwq700000gn/T/ipykernel_84059/2165798071.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chunk["proba"] = df_chunk["probas"].apply(lambda probas: float(probas[0][1]))
# Process chunk 2
# Process chunk 3
# Process chunk 4
# Process chunk 5
# Process chunk 6
# Process chunk 7
# Process chunk 8
# Process chunk 9
# Process chunk 10
# Process chunk 11
# Process chunk 12
# Process chunk 13
# Process chunk 14
# Process chunk 15
# Process chunk 16
# Process chunk 17
# Process chunk 18
# Process chunk 19
# Process chunk 20
# Process chunk 21
# Process chunk 22
# Process chunk 23
# Process chunk 24
# Process chunk 25
# Process chunk 26
# Process chunk 27
# Process chunk 28
# Process chunk 29
# Process chunk 30
# Process chunk 31
# Process chunk 32
# Process chunk 33
# Process chunk 34
# Process chunk 35
# Process chunk 36
# Process chunk 37
# Process chunk 38
# Process chunk 39
# Process chunk 40
# Process chunk 41
# Process chunk 42
# Process chunk 43
# Process chunk 44
# Process chunk 45
# Process chunk 46
# Process chunk 47
# Process chunk 48
# Process chunk 49
# Process chunk 50
# Process chunk 51
# Process chunk 52
# Process chunk 53
# Process chunk 54
# Process chunk 55
# Process chunk 56
# Process chunk 57
# Process chunk 58
# Process chunk 59
# Process chunk 60
# Process chunk 61
# Process chunk 62
# Process chunk 63
# Process chunk 64
# Process chunk 65
# Process chunk 66
# Process chunk 67
# Process chunk 68
# Process chunk 69
# Process chunk 70
# Process chunk 71
# Process chunk 72
# Process chunk 73
# Process chunk 74
# Process chunk 75
# Process chunk 76
# Process chunk 77
# Process chunk 78
# Process chunk 79
# Process chunk 80
# Process chunk 81
# Process chunk 82
# Process chunk 83
# Process chunk 84
# Process chunk 85
# Process chunk 86
# Process chunk 87
# Process chunk 88
# Process chunk 89
# Process chunk 90
# Process chunk 91
# Process chunk 92
# Process chunk 93
# Process chunk 94
# Process chunk 95
# Process chunk 96
# Process chunk 97
# Process chunk 98
# Process chunk 99
# Process chunk 100
# Process chunk 101
# Process chunk 102
# Process chunk 103
# Process chunk 104
# Process chunk 105
# Process chunk 106
# Process chunk 107
# Process chunk 108
# Process chunk 109
# Process chunk 110
# Process chunk 111
# Process chunk 112
# Process chunk 113
# Process chunk 114
# Process chunk 115
# Process chunk 116
# Process chunk 117
# Process chunk 118
# Process chunk 119
# Process chunk 454
# Process chunk 455
# Process chunk 456
# Process chunk 457
# Process chunk 458
# Process chunk 459
# Process chunk 460
# Process chunk 461
# Process chunk 462
# Process chunk 463
# Process chunk 464
# Process chunk 465
# Process chunk 466
# Process chunk 467
# Process chunk 468
# Process chunk 469
# Process chunk 470
# Process chunk 471
# Process chunk 472
# Process chunk 473
# Process chunk 474
# Process chunk 475
# Process chunk 476
# Process chunk 477
# Process chunk 478
# Process chunk 479
# Process chunk 480
# Process chunk 481
# Process chunk 482
# Process chunk 483
# Process chunk 484
# Process chunk 485
# Process chunk 486
# Process chunk 487
# Process chunk 488
# Process chunk 489
# Process chunk 490
# Process chunk 491
# Process chunk 492
# Process chunk 493
# Process chunk 494
# Process chunk 495
# Process chunk 496
# Process chunk 497
# Process chunk 498
# Process chunk 499
# Process chunk 500
# Process chunk 501
# Process chunk 502
# Process chunk 503
# Process chunk 504
# Process chunk 505
# Process chunk 506
# Process chunk 507
# Process chunk 508
# Process chunk 509
# Process chunk 510
# Process chunk 511
# Process chunk 512
# Process chunk 513
# Process chunk 514
# Process chunk 515
# Process chunk 516
# Process chunk 517
# Process chunk 518
# Process chunk 519
# Process chunk 520
# Process chunk 521
# Process chunk 522
# Process chunk 523
# Process chunk 524
# Process chunk 525

# %% [markdown]
# ### For each speaker, compute the number of times it appeared in the articles
# For now, the certainty probability of a quote's speaker being correct is not taken into account and every (newspaper,speaker) pair is kept.

# %%
NEWSPAPER_SPEAKER_COUNT_FILE = PROCESSED_DATA_FOLDER+"speaker-newspaper-2020.csv.bz2"

# %%
df = pd.read_csv(FILE_SPEAKERS,compression='bz2')
newspaper_speaker_count = df.groupby(['newspaper','speaker'],as_index=False).count()\
                            .rename(columns = {'proba':'count'})

# %%
newspaper_speaker_count
# Out:
#          newspaper          speaker  count
# 0          1011now     Adam Morfeld      4
# 1          1011now      Adam Schiff      2
# 2          1011now     Adrian Smith      2
# 3          1011now  Alexandra Brown      1
# 4          1011now  Alfonso Morales      1
# ...            ...              ...    ...
# 2446066  zigwheels   Srinivas Reddy      1
# 2446067  zigwheels       Toby Price      1
# 2446068  zigwheels     Yash Aradhya      1
# 2446069      zip06      Mike Caruso     16
# 2446070      zip06             None      2
#
# [2446071 rows x 3 columns]

# %%
newspaper_speaker_count.to_csv(NEWSPAPER_SPEAKER_COUNT_FILE,header = True,index=False, mode='w',compression='bz2')

# %% [markdown]
# ### Compute overall statistic on newspapers and speakers
# Important no threshold has been applied on speaker

# %%
df = pd.read_csv(NEWSPAPER_SPEAKER_COUNT_FILE,compression='bz2')

# %%
df.columns
# Out:
# Index(['newspaper', 'speaker', 'count'], dtype='object')

# %%
print(f'They are {len(df)} pairs of (newspapers,speakers)')
newspapers = set(newspaper_speaker_count['newspaper'])
print(f'They are {len(newspapers)} unique newspapers')
speakers = set(newspaper_speaker_count['speaker'])
print(f'They are {len(speakers)} unique speakers')
# Out:
# They are 2446071 pairs of (newspapers,speakers)
# They are 7362 unique newspapers
# They are 218414 unique speakers

# %%
speaker_unique_occurence = df[['newspaper','speaker']].groupby('speaker',as_index=False).count()\
                    .rename(columns = {'newspaper':'unique_newspaper_quotes'})

# %%
speaker_unique_occurence.nlargest(100,columns=['unique_newspaper_quotes'])
# Out:
#                            speaker  unique_newspaper_quotes
# 153120                        None                     6999
# 164974      President Donald Trump                     2822
# 164984             President Trump                     2030
# 198999  Tedros Adhanom Ghebreyesus                     1954
# 25136                Boris Johnson                     1890
# 21523               Bernie Sanders                     1813
# 14907                Anthony Fauci                     1755
# 10955                 Andrew Cuomo                     1707
# 96844                    Joe Biden                     1681
# 148530                Nancy Pelosi                     1665
# 55603                 Donald Trump                     1601
# 60006             Elizabeth Warren                     1557
# 144395                  Mike Pence                     1477
# 144427                 Mike Pompeo                     1467
# 38488                Chuck Schumer                     1444
# 116591                 Kobe Bryant                     1431
# 69197                 Gavin Newsom                     1380
# 145569             Mitch McConnell                     1362
# 160714              Pete Buttigieg                     1348
# 194475              Steven Mnuchin                     1348
# 108536              Justin Trudeau                     1332
# 23188               Bill de Blasio                     1282
# 2258                   Adam Schiff                     1255
# 184844              Scott Morrison                     1248
# 212249                William Barr                     1181
# 131869                  Mark Esper                     1176
# 188452                  Shinzo Abe                     1176
# 54834                 Dominic Raab                     1168
# 5536                     Alex Azar                     1167
# 213831                  Xi Jinping                     1166
# 139519           Michael Bloomberg                     1156
# 9412                 Amy Klobuchar                     1150
# 136019                Matt Hancock                     1145
# 143421              Mike Bloomberg                     1127
# 93231                 Jerome Adams                     1104
# 164604                Pope Francis                     1102
# 7185                  Ali Khamenei                     1101
# 191757           Stephanie Grisham                     1100
# 146004        Mohammad Javad Zarif                     1096
# 145691                 Mitt Romney                     1086
# 76854               Hassan Rouhani                     1067
# 203713                   Tom Hanks                     1061
# 15530             Antonio Guterres                     1054
# 123106              Lindsey Graham                     1054
# 61155              Emmanuel Macron                     1053
# 51568                 Deborah Birx                     1041
# 210009              Vladimir Putin                     1016
# 93263                Jerome Powell                      979
# 200139                 Thomas Bach                      977
# 138606               Melania Trump                      970
# 144546                   Mike Ryan                      964
# 148783               Narendra Modi                      960
# 72077               Giuseppe Conte                      957
# 120311                LeBron James                      954
# 12947                Angela Merkel                      948
# 90846                   Jeff Bezos                      942
# 21027           Benjamin Netanyahu                      925
# 207643        Ursula von der Leyen                      913
# 4298               Alan Dershowitz                      911
# 74365               Greta Thunberg                      907
# 165402          Queen Elizabeth II                      900
# 196194               Susan Collins                      899
# 165037                Prince Harry                      897
# 96620              Joaquin Phoenix                      894
# 118461             Lamar Alexander                      892
# 89857                   Jay Inslee                      891
# 180750                  Sadiq Khan                      890
# 141638                Michael Ryan                      883
# 101496                John Roberts                      881
# 60356                    Elon Musk                      880
# 74381             Gretchen Whitmer                      878
# 56883            Duchess of Sussex                      863
# 186920           Shane Fitzsimmons                      863
# 69562                  Geng Shuang                      860
# 177007                Ron DeSantis                      859
# 25476                    Brad Pitt                      846
# 201570                    Tim Cook                      837
# 118900                Larry Kudlow                      832
# 6777      Alexandria Ocasio-Cortez                      831
# 23194                Billie Eilish                      831
# 163215                 Phil Murphy                      827
# 138398               Meghan Markle                      825
# 123529              Lisa Murkowski                      824
# 172654                 Rishi Sunak                      818
# 89975                  Jay Sekulow                      805
# 72121           Gladys Berejiklian                      803
# 61731                Eric Garcetti                      802
# 133256             Mark Zuckerberg                      801
# 76776             Harvey Weinstein                      800
# 164965      President Barack Obama                      799
# 78546              Hillary Clinton                      793
# 210097         Volodymyr Zelenskiy                      791
# 89554                  Javad Zarif                      781
# 117006        Kristalina Georgieva                      771
# 204384                  Tom Steyer                      766
# 169213        Recep Tayyip Erdogan                      764
# 192240                Stephen Hahn                      763
# 203313                   Tom Brady                      762
# 156363               Pat Cipollone                      761
# 83273               Jacinda Ardern                      757

# %%
speaker_unique_occurence.describe()
# Out:
#        unique_newspaper_quotes
# count            218414.000000
# mean                 11.199241
# std                  43.472728
# min                   1.000000
# 25%                   1.000000
# 50%                   2.000000
# 75%                   6.000000
# max                6999.000000

# %%
speaker_total_occurence = df.groupby('speaker',as_index=False).aggregate({'count':'sum'})\
                                .rename(columns = {'count':'total_newspaper_quotes'})

# %%
speaker_total_occurence.nlargest(100,columns=['total_newspaper_quotes'])
# Out:
#                            speaker  total_newspaper_quotes
# 153120                        None                 5857313
# 164974      President Donald Trump                  259733
# 25136                Boris Johnson                   86130
# 96844                    Joe Biden                   84389
# 21523               Bernie Sanders                   69519
# 198999  Tedros Adhanom Ghebreyesus                   67662
# 184844              Scott Morrison                   59476
# 10955                 Andrew Cuomo                   53986
# 164984             President Trump                   53382
# 14907                Anthony Fauci                   49207
# 148530                Nancy Pelosi                   46870
# 60006             Elizabeth Warren                   42824
# 136019                Matt Hancock                   41478
# 144427                 Mike Pompeo                   41380
# 2258                   Adam Schiff                   34679
# 160714              Pete Buttigieg                   31718
# 55603                 Donald Trump                   31357
# 38488                Chuck Schumer                   30077
# 108536              Justin Trudeau                   30048
# 104690               Jose Mourinho                   25987
# 145569             Mitch McConnell                   25442
# 54834                 Dominic Raab                   24324
# 148783               Narendra Modi                   24193
# 160540               Pep Guardiola                   22335
# 69197                 Gavin Newsom                   22123
# 9412                 Amy Klobuchar                   21409
# 172654                 Rishi Sunak                   20820
# 108163                Jurgen Klopp                   20580
# 121216                Leo Varadkar                   20552
# 144395                  Mike Pence                   20028
# 151757             Nicola Sturgeon                   19647
# 144867                Mikel Arteta                   18730
# 66171                Frank Lampard                   18402
# 116591                 Kobe Bryant                   18252
# 164604                Pope Francis                   18213
# 131869                  Mark Esper                   17774
# 23188               Bill de Blasio                   17399
# 194475              Steven Mnuchin                   17151
# 134995           Mary Lou McDonald                   16474
# 72121           Gladys Berejiklian                   16445
# 15530             Antonio Guterres                   16356
# 139519           Michael Bloomberg                   15815
# 26233               Brendan Murphy                   15474
# 76854               Hassan Rouhani                   14684
# 112024                Keir Starmer                   14392
# 143421              Mike Bloomberg                   14165
# 212249                William Barr                   13704
# 78546              Hillary Clinton                   13294
# 58100                  Eddie Jones                   13270
# 213831                  Xi Jinping                   13223
# 56883            Duchess of Sussex                   13162
# 92867                Jeremy Corbyn                   13128
# 21027           Benjamin Netanyahu                   12852
# 123106              Lindsey Graham                   12698
# 26258              Brendan Rodgers                   11841
# 7185                  Ali Khamenei                   11810
# 210009              Vladimir Putin                   11643
# 43981               Daniel Andrews                   11583
# 120311                LeBron James                   11534
# 191757           Stephanie Grisham                   11461
# 123533                  Lisa Nandy                   11387
# 14057        Annastacia Palaszczuk                   11344
# 93231                 Jerome Adams                   11274
# 73529                 Grant Shapps                   11206
# 165037                Prince Harry                   11042
# 153454              Novak Djokovic                   10952
# 207643        Ursula von der Leyen                   10943
# 145691                 Mitt Romney                   10751
# 73830                    Greg Hunt                   10678
# 180750                  Sadiq Khan                   10662
# 61155              Emmanuel Macron                   10619
# 51568                 Deborah Birx                   10496
# 5536                     Alex Azar                   10161
# 105566             Josh Frydenberg                   10080
# 163215                 Phil Murphy                   10060
# 177007                Ron DeSantis                    9746
# 140317                Michael Gove                    9738
# 4298               Alan Dershowitz                    9705
# 200139                 Thomas Bach                    9690
# 165118                 Priti Patel                    9675
# 193003                 Steve Bruce                    9654
# 216433             Zinedine Zidane                    9541
# 169045         Rebecca Long-Bailey                    9470
# 51337                   Dean Smith                    9424
# 83273               Jacinda Ardern                    9308
# 74381             Gretchen Whitmer                    9246
# 146004        Mohammad Javad Zarif                    9213
# 142301              Micheal Martin                    8944
# 169213        Recep Tayyip Erdogan                    8915
# 11976                  Andrew Yang                    8738
# 30755              Carlo Ancelotti                    8578
# 16945              Arvind Kejriwal                    8541
# 25476                    Brad Pitt                    8467
# 16325                Arlene Foster                    8359
# 49590                  David Moyes                    8306
# 138606               Melania Trump                    8293
# 74365               Greta Thunberg                    8187
# 176305               Roger Federer                    8113
# 189255               Simon Coveney                    8105
# 93263                Jerome Powell                    8072

# %%
speaker_total_occurence.describe()
# Out:
#        total_newspaper_quotes
# count            2.184140e+05
# mean             7.809723e+01
# std              1.255878e+04
# min              1.000000e+00
# 25%              2.000000e+00
# 50%              6.000000e+00
# 75%              1.900000e+01
# max              5.857313e+06

# %%
newspaper_speaker_count = df.groupby('newspaper',as_index=False).aggregate({'speaker':'count'})\
                            .rename(columns = {'speaker':'speaker_count'})

# %%
newspaper_speaker_count.nlargest(100,columns=['speaker_count'])
# Out:
#                  newspaper  speaker_count
# 4055                   msn          16656
# 784              breitbart           9485
# 6872       washingtontimes           9271
# 5439                sfgate           8896
# 2954            indiatimes           7340
# 4518               nytimes           7299
# 5405          seattletimes           6982
# 2938           independent           6537
# 5686      stamfordadvocate           6454
# 890        businessinsider           6440
# 1478                ctpost           6439
# 6140               thehour           6307
# 4340             newstimes           6256
# 4378            nhregister           6098
# 5769                 stuff           6029
# 2980            infosurhoy           5640
# 3417                  kvia           5497
# 4523                nzcity           5496
# 6041            thecourier           5449
# 4127          mysanantonio           5381
# 2302               foxnews           5377
# 1178                 chron           5308
# 2882               ibtimes           5273
# 5551                   smh           5272
# 803          brisbanetimes           5241
# 6323               thestar           5192
# 6118           theguardian           5179
# 4325                newsok           5164
# 528                    bbc           5099
# 5701           startribune           5086
# 2982               infotel           4962
# 3918                mirror           4925
# 5966                theage           4904
# 1111       channelnewsasia           4842
# 2481                    go           4734
# 2060           expressnews           4732
# 7242                  wtop           4629
# 2058               express           4589
# 6331                thesun           4580
# 744            bostonglobe           4565
# 7165             wordpress           4545
# 7239                  wtmj           4506
# 2059        expressandstar           4499
# 4283                news18           4471
# 1276                   cnn           4443
# 2948         indianexpress           4437
# 3374                   ksl           4394
# 34                 570news           4323
# 621         bignewsnetwork           4314
# 5799    sunshinecoastdaily           4130
# 2593         greenwichtime           4109
# 5689              standard           4095
# 3237               kdhnews           4090
# 1072              cbslocal           4080
# 6022          thechronicle           4065
# 1480               ctvnews           4054
# 2033          eveningtimes           4025
# 3075         irishexaminer           4023
# 850         bucksfreepress           4014
# 5921             telegraph           4014
# 4282                news12           3975
# 6882               watoday           3915
# 5028                    qt           3907
# 4280             news-mail           3899
# 1211              citynews           3891
# 2626           gympietimes           3889
# 6209    themorningbulletin           3872
# 779           breakingnews           3868
# 1554          dailymercury           3864
# 4525              nzherald           3847
# 2750        hindustantimes           3832
# 2308  frasercoastchronicle           3827
# 1533         dailyexaminer           3814
# 6864      warwickdailynews           3793
# 7338     yourlocalguardian           3787
# 2247                forbes           3786
# 4444          northernstar           3786
# 564       belfasttelegraph           3759
# 4646            oxfordmail           3757
# 7032       whitsundaytimes           3757
# 6132              thehindu           3755
# 6995                  wftv           3748
# 6113       theglobeandmail           3733
# 2451     gladstoneobserver           3728
# 6235       thenorthernecho           3710
# 2868            hypervocal           3692
# 5608       southwalesargus           3682
# 6406       thisiswiltshire           3670
# 5474        shropshirestar           3653
# 7325             yorkpress           3628
# 4964             prokerala           3619
# 4122           mynorthwest           3616
# 753        bournemouthecho           3615
# 5999         theboltonnews           3607
# 3368                  ksat           3580
# 3915            miragenews           3571
# 4290           newsandstar           3556
# 3517            leaderlive           3550
# 5976              theargus           3546
# 1290    coffscoastadvocate           3522

# %%
newspaper_speaker_count.describe()
# Out:
#        speaker_count
# count    7362.000000
# mean      332.256316
# std       803.901198
# min         1.000000
# 25%        11.000000
# 50%        53.000000
# 75%       218.750000
# max     16656.000000

# %%
newspaper_quote_count = df.groupby('newspaper',as_index=False).aggregate({'count':'sum'})\
                        .rename(columns={'count':'quote_count'})

# %%
newspaper_quote_count.nlargest(100,columns=['quote_count'])
# Out:
#                  newspaper  quote_count
# 1890               einnews       267567
# 4055                   msn       240577
# 4289               news965       127998
# 7152                  wokv       119616
# 890        businessinsider       102126
# 784              breitbart        98428
# 6872       washingtontimes        81833
# 7222              wsbradio        77257
# 2954            indiatimes        75690
# 4212             nbcsports        72913
# 4518               nytimes        70478
# 2302               foxnews        66660
# 5439                sfgate        64866
# 2370           gamereactor        57670
# 2938           independent        56300
# 4208               nbcnews        55788
# 5551                   smh        54683
# 4325                newsok        54674
# 3362                  krmg        54602
# 5769                 stuff        53077
# 6443         timesofisrael        52930
# 4282                news12        52282
# 803          brisbanetimes        51100
# 5686      stamfordadvocate        49797
# 1478                ctpost        49612
# 2058               express        49140
# 6140               thehour        49080
# 4340             newstimes        48458
# 7239                  wtmj        47390
# 4378            nhregister        47088
# 5966                theage        46703
# 3918                mirror        46170
# 5405          seattletimes        45565
# 3417                  kvia        44732
# 1276                   cnn        43934
# 4525              nzherald        41582
# 4345              newsweek        40887
# 3374                   ksl        40159
# 1982                  espn        40036
# 2481                    go        39778
# 2882               ibtimes        39479
# 779           breakingnews        38164
# 4523                nzcity        37573
# 1480               ctvnews        37502
# 1111       channelnewsasia        36664
# 1178                 chron        36221
# 6041            thecourier        35605
# 744            bostonglobe        35582
# 6331                thesun        35166
# 982          canberratimes        34548
# 2980            infosurhoy        33747
# 5773                   stv        33669
# 2060           expressnews        33466
# 2868            hypervocal        33381
# 4127          mysanantonio        33068
# 4283                news18        32708
# 1632          deccanherald        32340
# 6995                  wftv        32267
# 1073               cbsnews        31907
# 5799    sunshinecoastdaily        31314
# 6882               watoday        30793
# 6022          thechronicle        30354
# 6118           theguardian        30178
# 3237               kdhnews        29989
# 2948         indianexpress        29826
# 6323               thestar        29736
# 3077           irishmirror        29566
# 1577             dailystar        29499
# 2982               infotel        29402
# 1128            cheatsheet        29177
# 4280             news-mail        28951
# 2593         greenwichtime        28809
# 3401                  ktvz        28710
# 5028                    qt        28689
# 6209    themorningbulletin        28689
# 4444          northernstar        28678
# 2626           gympietimes        28628
# 2033          eveningtimes        28467
# 850         bucksfreepress        28429
# 1554          dailymercury        28314
# 2308  frasercoastchronicle        28178
# 2750        hindustantimes        28072
# 2059        expressandstar        28043
# 1247        clickondetroit        28018
# 6864      warwickdailynews        27999
# 564       belfasttelegraph        27960
# 5689              standard        27910
# 5001                 pulse        27866
# 7032       whitsundaytimes        27846
# 5701           startribune        27831
# 1533         dailyexaminer        27738
# 315         arkansasonline        27719
# 2027             eurosport        27672
# 2992              inquirer        27668
# 528                    bbc        27386
# 2451     gladstoneobserver        27251
# 5608       southwalesargus        27228
# 6235       thenorthernecho        27109
# 4646            oxfordmail        27027
# 7242                  wtop        27011

# %%
newspaper_quote_count.describe()
# Out:
#          quote_count
# count    7362.000000
# mean     2316.969302
# std      7791.179536
# min         1.000000
# 25%        34.000000
# 50%       221.500000
# 75%      1117.500000
# max    267567.000000

# %% [markdown]
# #### Other stats:
# Repartition of speaker in newspaper (eg: 50% trump, ...)
# Show and then tf-idf

# %% [markdown]
# ### Thresholding decisions
#
# If we keep everything, the newspaper-speaker_count matrix will be of size:
# newspapers_count x speaker_count = 7148 x 218 413 = 1 561 216 124 which is huge even though the obtained matrix will be sparse.
# We must decide which newspaper to keep
# We must decide which speakers to keep
# We decide probability threshold for a speaker to be correctly attributed to a quote.
